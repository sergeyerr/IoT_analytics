# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
date = 'Дата замера'
hole = 'Скважина'
x1 = 'Способ эксплуатации'
x2 = 'Режим'
X = [x1, x2]
y1 = 'Рпр(ТМ)'
y2 = 'Рзаб(Рпр)'
y3 = 'Рзаб(Нд)'
y4 = 'Рзаб(иссл)'
Y = [y1, y2, y3, y4]
def load_some_data(path, separ = ':'):
    return pd.read_csv(path, sep=separ, parse_dates = [date], index_col = date,  encoding='cp1251')

# %%
df = load_some_data('data2.csv')
df.head()
#cats_x1 = df[x1].astype('category').cat.categories
#df[x1] = df[x1].astype('category').cat.codes
#cats_x2 = df[x2].astype('category').cat.categories
#df[x2] = df[x2].astype('category').cat.codes
#df = df.dropna(0)
#df =  df.drop_duplicates()
#df[df[hole] == '409'].describe()
#df[df[hole] == '409'].describe()
# Out:
#             Скважина Способ эксплуатации Режим  Рпр(ТМ)  Рзаб(Рпр)  Рзаб(Нд)  \
# Дата замера
# 2018-01-01         1                 NaN   ПКВ      NaN        NaN      44.2
# 2018-01-02         1                 NaN   ПКВ      NaN        NaN      43.0
# 2018-01-03         1                 NaN   ПКВ      NaN        NaN      44.2
# 2018-01-04         1                 NaN   ПКВ      NaN        NaN      44.2
# 2018-01-05         1                 NaN   ПКВ      NaN        NaN      44.2
#
#              Рзаб(иссл)
# Дата замера
# 2018-01-01         55.0
# 2018-01-02         55.0
# 2018-01-03         55.0
# 2018-01-04         55.0
# 2018-01-05         55.0

# %%
from sklearn import preprocessing


def normalize_col(df, cols):
    res = df.copy()
    for col in cols:
        x = res[[col]].values #returns a numpy array
        min_max_scaler = preprocessing.MinMaxScaler()
        x_scaled = min_max_scaler.fit_transform(x)
        res[col] = pd.DataFrame(x_scaled)
    return res

# %%
# %matplotlib inline
def draw_plot(name_hole, data_to_draw, what_to_do ='see'):
    formatter = ticker.FormatStrFormatter('%.0f')
    fig, axes = plt.subplots(1,2)
    for y in Y:
        axes[0].plot(data_to_draw[y], label = y)
    axes[0].legend()
    axes[0].set_title('Измерения давлений')
    axes[0].set_xlabel(date, fontsize = 12)
    axes[0].set_ylabel('P', fontsize = 12)
    
    axes[1].plot(data_to_draw[x1], label = x1)
    axes[1].plot(data_to_draw[x2], label = x2)
    axes[1].set_title(x1 + 'and' + x2)
    axes[1].legend()
    axes[1].set_xlabel(date, fontsize = 12)
    axes[1].set_ylabel('№', fontsize = 12)
    axes[1].yaxis.set_major_formatter(formatter)
    fig.set_figwidth(15)
    fig.set_figheight(8)
    fig.suptitle(hole + ' ' + str(name_hole))
    plt.legend()
    if (what_to_do == 'save'):
        plt.savefig(create_directory('diagrams') + '/' + name_hole + '.png',
                    dpi = 100, format = 'png')
    else:
        plt.show()

# %%
#test = normalize_col(df, Y)
#test

# %%
for hol in df[hole].unique():
    print(hol)
# Out:
# 1
# 10
# 1001
# 1001-2
# 1002
# 1002-1
# 1004-1
# 1004-2
# 1006-2
# 1007
# 1007-1
# 1007-2
# 1009
# 1009-2
# 101
# 1010
# 1010-1
# 1012
# 1012-1
# 1012-2
# 1014
# 1014-1
# 1014-2
# 1015
# 1015-1
# 1016
# 1016-1
# 1017-2
# 1018
# 1018-1
# 1018-2
# 1019
# 1019-1
# 1019-2
# 102
# 1020
# 1020-2
# 1021-1
# 1021-2
# 1022
# 1022-1
# 1022-2
# 1025-2
# 1027
# 1027-1
# 1027-2
# 1028-1
# 1028-2
# 1029-1
# 1029-2
# 1030
# 1030-2
# 1033
# 1033-1
# 1033-2
# 1034
# 1034-1
# 1034-2
# 1034-3
# 1036-1
# 1036-2
# 1037-1
# 1040
# 1040-1
# 1040-2
# 1044
# 1044-1
# 3248
# 3249
# 3252
# 3256
# 3257
# 3259
# 3260
# 3285
# 3291
# 3292
# 3293
# 3294
# 3297
# 3299
# 3306
# 3307
# 3315
# 3316
# 3321
# 3322
# 3325
# 3411
# 3413
# 3419
# 3500
# 35-1
# 3999
# 400
# 40-1
# 406
# 409
# 41-1
# 418
# 419
# 41р
# 43468
# 43469
# 43470
# 43475
# 43476
# 43477
# 43479
# 43480
# 43484
# 43485
# 43486
# 43493
# 43494
# 43495
# 43498
# 43499
# 43500
# 43501
# 43508
# 43516
# 43519
# 43527
# 43528
# 43537
# 43р
# 449
# 44р
# 45р
# 47р
# 499
# 4р
# 5
# 50
# 500
# 501
# 501-1
# 503
# 510
# 511
# 515
# 517
# 518
# 51д
# 521
# 522
# 526
# 527
# 528
# 5296
# 530
# 530-1
# 5303
# 5304
# 5305
# 5307
# 5308
# 531
# 5310
# 5311
# 5312
# 5313
# 5314
# 5315
# 5316
# 5317
# 5319
# 532
# 5320
# 5323
# 5325
# 5326
# 5327
# 5328
# 533
# 5330
# 5332
# 5333
# 5334
# 5335
# 5337
# 5351
# 5352
# 536
# 537
# 539
# 543
# 546
# 547-1
# 548
# 550
# 551
# 552
# 553
# 554
# 555
# 556
# 556-1
# 559
# 560
# 562
# 563
# 564
# 565
# 566
# 567
# 57
# 576
# 595-1
# 599-1
# 5р
# 61
# 613
# 616
# 617
# 61Р
# 62-1
# 621
# 62-2
# 622
# 62-3
# 628
# 629а
# 640-1
# 663
# 669
# 69
# 69р
# 6р
# 7
# 70-1
# 70-2
# 703
# 704
# 705
# 706
# 707
# 708
# 710
# 711
# 712
# 715
# 73
# 8
# 86
# 95-1
# 95-2

# %%
draw_plot(406, df[df[hole] == '406'])
# Out:
# D:\anaconda\envs\foo\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-2fe0980d31de> in <module>
# ----> 1 draw_plot(406, df[df[hole] == '406'])
#
# <ipython-input-4-ba48b879417b> in draw_plot(name_hole, data_to_draw, what_to_do)
#      10     axes[0].set_ylabel('P', fontsize = 12)
#      11
# ---> 12     axes[1].plot(data_to_draw[x1], label = x1)
#      13     axes[1].plot(data_to_draw[x2], label = x2)
#      14     axes[1].set_title(x1 + 'and' + x2)
#
# D:\anaconda\envs\foo\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# D:\anaconda\envs\foo\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1610
#    1611         for line in self._get_lines(*args, **kwargs):
# -> 1612             self.add_line(line)
#    1613             lines.append(line)
#    1614
#
# D:\anaconda\envs\foo\lib\site-packages\matplotlib\axes\_base.py in add_line(self, line)
#    1893             line.set_clip_path(self.patch)
#    1894
# -> 1895         self._update_line_limits(line)
#    1896         if not line.get_label():
#    1897             line.set_label('_line%d' % len(self.lines))
#
# D:\anaconda\envs\foo\lib\site-packages\matplotlib\axes\_base.py in _update_line_limits(self, line)
#    1915         Figures out the data limit of the given line, updating self.dataLim.
#    1916         """
# -> 1917         path = line.get_path()
#    1918         if path.vertices.size == 0:
#    1919             return
#
# D:\anaconda\envs\foo\lib\site-packages\matplotlib\lines.py in get_path(self)
#     943         """
#     944         if self._invalidy or self._invalidx:
# --> 945             self.recache()
#     946         return self._path
#     947
#
# D:\anaconda\envs\foo\lib\site-packages\matplotlib\lines.py in recache(self, always)
#     643         if always or self._invalidy:
#     644             yconv = self.convert_yunits(self._yorig)
# --> 645             y = _to_unmasked_float_array(yconv).ravel()
#     646         else:
#     647             y = self._y
#
# D:\anaconda\envs\foo\lib\site-packages\matplotlib\cbook\__init__.py in _to_unmasked_float_array(x)
#    1363         return np.ma.asarray(x, float).filled(np.nan)
#    1364     else:
# -> 1365         return np.asarray(x, float)
#    1366
#    1367
#
# D:\anaconda\envs\foo\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: could not convert string to float: 'Электропогружным насосом'

# %%
from influxdb import DataFrameClient
from numpy import nan

def write_to_inf(_host='localhost', _port=8086, cluster = 'raw_data', db = 'holes'):


    client = DataFrameClient(host=_host, port=_port, database = db)
    to_write = df.copy()
    to_write[[x1, x2]] = to_write[[x1,x2]].fillna(-1)
    print(to_write.head())
    #print("Write DataFrame with Tags")
    #client.write_points(df, cluster, tags = {hole : hole, x1: x1, x2: x2})
    grouped = to_write.groupby([hole,x1, x2])
    #for group in grouped.groups:
        #tag1, tag2, tag3 = group
        #tags = dict(hole = tag1, x1=tag2, x2 = tag3)
        #sub_df = df.where((df[hole] == tag1) & (df[x1] == tag2) & (df[x2] == tag3))[Y]
        #sub_df = grouped.get_group(group)
        #sub_df.loc[sub_df[x1] == -1, x1] = nan
        #sub_df.loc[sub_df[x2] == -1, x1] = nan
       # dfclient.write_points(sub_df, measurement, tags=tags)

# %%
write_to_inf()
# Out:
# D:\anaconda\envs\foo\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
